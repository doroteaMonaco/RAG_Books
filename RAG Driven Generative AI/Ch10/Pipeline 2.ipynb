# %% [markdown]
# # The Vector Store Administrator

# %%
from IPython.display import HTML # to display videos
import base64 # to encode videos as base64
from base64 import b64encode # to encode videos as base64
import os # to interact with the operating system
import subprocess # to run commands
import time # to measure execution time
import csv # to save comments
import uuid # to generate unique ids
import cv2 # to split videos
from PIL import Image # to display videos
import pandas as pd # to display comments
import numpy as np # to use Numerical Python
from io import BytesIO #for a binary stream of data in memory

# %%
import requests

def download(directory, filename):
    base_url = 'https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/'
    file_url = f"{base_url}{directory}/{filename}"
    print("Trying to download:", file_url)
    try:
        response = requests.get(file_url)
        response.raise_for_status()
        with open(filename, 'wb') as f:
            f.write(response.content)
        print(f"Downloaded '{filename}' successfully.")
    except Exception as e:
        print(f"Failed to download '{filename}': {e}")

# %%
# !pip install pinecone-client==4.1.1
# Out:
# Collecting pinecone-client==4.1.1
#   Downloading pinecone_client-4.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: certifi>=2019.11.17 in C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pinecone-client==4.1.1) (2026.2.25)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pinecone-client==4.1.1) (0.0.7)
# Requirement already satisfied: tqdm>=4.64.1 in C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pinecone-client==4.1.1) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pinecone-client==4.1.1) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pinecone-client==4.1.1) (2.6.3)
# Requirement already satisfied: colorama in C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages (from tqdm>=4.64.1->pinecone-client==4.1.1) (0.4.6)
# Downloading pinecone_client-4.1.1-py3-none-any.whl (216 kB)
# Installing collected packages: pinecone-client
#   Attempting uninstall: pinecone-client
#     Found existing installation: pinecone-client 3.0.3
#     Uninstalling pinecone-client-3.0.3:
#       Successfully uninstalled pinecone-client-3.0.3
# Successfully installed pinecone-client-4.1.1
# WARNING: Ignoring invalid distribution ~ (C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
import pinecone

# %%
import os
from dotenv import load_dotenv
load_dotenv()
pinecone_api_key = os.getenv("PINECONE_API_KEY")
pinecone_environment = os.getenv("PINECONE_ENVIRONMENT")

if not pinecone_api_key or not pinecone_environment:
    raise ValueError("Pinecone API key and environment must be set in the .env file.")
else:
    print("Pinecone API key and environment loaded successfully.")
# Out:
# Pinecone API key and environment loaded successfully.

# %%
lfile = [
    "jogging1.mp4.csv",
    "jogging2.mp4.csv",
    "skiing1.mp4.csv",
    "soccer_pass.mp4.csv",
    "soccer_player_head.mp4.csv",
    "soccer_player_running.mp4.csv",
    "surfer1.mp4.csv",
    "surfer2.mp4.csv",
    "swimming1.mp4.csv",
    "walking1.mp4.csv",
    "ball_passing_goal.mp4.csv",
    "basketball1.mp4.csv",
    "basketball2.mp4.csv",
    "basketball3.mp4.csv",
    "basketball4.mp4.csv",
    "basketball5.mp4.csv",
    "female_player_after_scoring.mp4.csv",
    "football1.mp4.csv",
    "football2.mp4.csv",
    "hockey1.mp4.csv"
]

# %%
lf=len(lfile)
print(lf)
# Out:
# 20

# %%
directory = "Chapter10/comments"
for i in range(lf):
  file_name=lfile[i]
  print(file_name)
  download(directory,file_name)
# Out:
# jogging1.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/jogging1.mp4.csv
# Downloaded 'jogging1.mp4.csv' successfully.
# jogging2.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/jogging2.mp4.csv
# Downloaded 'jogging2.mp4.csv' successfully.
# skiing1.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/skiing1.mp4.csv
# Downloaded 'skiing1.mp4.csv' successfully.
# soccer_pass.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/soccer_pass.mp4.csv
# Downloaded 'soccer_pass.mp4.csv' successfully.
# soccer_player_head.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/soccer_player_head.mp4.csv
# Downloaded 'soccer_player_head.mp4.csv' successfully.
# soccer_player_running.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/soccer_player_running.mp4.csv
# Downloaded 'soccer_player_running.mp4.csv' successfully.
# surfer1.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/surfer1.mp4.csv
# Downloaded 'surfer1.mp4.csv' successfully.
# surfer2.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/surfer2.mp4.csv
# Downloaded 'surfer2.mp4.csv' successfully.
# swimming1.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/swimming1.mp4.csv
# Downloaded 'swimming1.mp4.csv' successfully.
# walking1.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/walking1.mp4.csv
# Downloaded 'walking1.mp4.csv' successfully.
# alpinist1.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/alpinist1.csv
# Failed to download 'alpinist1.csv': 404 Client Error: Not Found for url: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/alpinist1.csv
# ball_passing_goal.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/ball_passing_goal.mp4.csv
# Downloaded 'ball_passing_goal.mp4.csv' successfully.
# basketball1.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/basketball1.mp4.csv
# Downloaded 'basketball1.mp4.csv' successfully.
# basketball2.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/basketball2.mp4.csv
# Downloaded 'basketball2.mp4.csv' successfully.
# basketball3.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/basketball3.mp4.csv
# Downloaded 'basketball3.mp4.csv' successfully.
# basketball4.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/basketball4.mp4.csv
# Downloaded 'basketball4.mp4.csv' successfully.
# basketball5.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/basketball5.mp4.csv
# Downloaded 'basketball5.mp4.csv' successfully.
# female_player_after_scoring.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/female_player_after_scoring.mp4.csv
# Downloaded 'female_player_after_scoring.mp4.csv' successfully.
# football1.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/football1.mp4.csv
# Downloaded 'football1.mp4.csv' successfully.
# football2.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/football2.mp4.csv
# Downloaded 'football2.mp4.csv' successfully.
# hockey1.mp4.csv
# Trying to download: https://raw.githubusercontent.com/Denis2054/RAG-Driven-Generative-AI/main/Chapter10/comments/hockey1.mp4.csv
# Downloaded 'hockey1.mp4.csv' successfully.

# %%
import os

directory = "../Ch10/comments"
for file in lfile:
    file_path = os.path.join(directory, file) 
    print(f"Checking if file exists: {file_path}, Exists: {os.path.exists(file_path)}")
# Out:
# Checking if file exists: ../Ch10/comments\jogging1.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\jogging2.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\skiing1.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\soccer_pass.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\soccer_player_head.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\soccer_player_running.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\surfer1.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\surfer2.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\swimming1.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\walking1.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\ball_passing_goal.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\basketball1.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\basketball2.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\basketball3.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\basketball4.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\basketball5.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\female_player_after_scoring.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\football1.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\football2.mp4.csv, Exists: True
# Checking if file exists: ../Ch10/comments\hockey1.mp4.csv, Exists: True

# %%
# Define the directory containing your files
directory = "../Ch10/comments/"

column_names = ['ID', 'FrameNumber', 'Comment', 'FileName']

df_list = []

for file in lfile:
    file_path = os.path.join(directory, file) 
    try:
        df_temp = pd.read_csv(file_path, names=column_names, header=None)
        df_list.append(df_temp)  
    except pd.errors.EmptyDataError:
        print(f"No data in {file}. File is skipped.")
    except pd.errors.ParserError:
        print(f"Parsing error in {file}. Check file format. File is skipped.")
    except Exception as e:
        print(f"An error occurred with {file}: {e}")


dfl = pd.concat(df_list, ignore_index=True)
dfl
# Out:
#                                        ID  FrameNumber  \
# 0                                      ID  FrameNumber
# 1    c6850e1f-9a20-4b44-96b3-9b75ae3a603d            3
# 2    046b105b-4f94-420f-b66b-5af70bd02ac5            7
# 3    b56e343b-8427-4c74-8fd5-9d10895b9e1f           11
# 4    556604cd-d4d9-4476-89b4-8659b1670c74           15
# ..                                    ...          ...
# 837  5a630329-6ed2-49e1-953a-a620c718cd9d          135
# 838  918eda74-7234-4a5b-8262-e37e7e4ebb3d          139
# 839  0e498059-43e8-4f57-bf08-69542e060573          143
# 840  01355e9e-6f42-446e-9329-fb7eb9e1fe33          147
# 841  7e38964d-e98a-4813-8a6f-126b0ae04b72          151
#
#                                                Comment      FileName
# 0                                              Comment      FileName
# 1    This image shows two individuals walking on a ...  jogging1.mp4
# 2    The image shows a forested area with tall tree...  jogging1.mp4
# 3    In the image, there is a person who appears to...  jogging1.mp4
# 4    The image shows a person walking on a path thr...  jogging1.mp4
# ..                                                 ...           ...
# 837  In the image, there is a group of American foo...   hockey1.mp4
# 838  This image shows a scene of American football ...   hockey1.mp4
# 839  In this image, we see a group of American foot...   hockey1.mp4
# 840  This image shows a group of people playing Ame...   hockey1.mp4
# 841  This image captures a moment from an American ...   hockey1.mp4
#
# [842 rows x 4 columns]

# %%
number_of_lines = len(dfl)
print("Number of lines: ",number_of_lines)
# Out:
# Number of lines:  842

# %%
df = dfl.dropna()

# %%
number_of_lines = len(df)
print("Number of lines: ",number_of_lines)
# Out:
# Number of lines:  842

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842 entries, 0 to 841
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           842 non-null    object
#  1   FrameNumber  842 non-null    object
#  2   Comment      842 non-null    object
#  3   FileName     842 non-null    object
# dtypes: object(4)
# memory usage: 26.4+ KB

# %% [markdown]
# ### Chunking and embedding the dataset

# %%
chunks = []

for index, row in df.iterrows():
    chunks.append(row['Comment'])  # Each 'Comment' becomes its own chunk

print(f"Total number of chunks: {len(chunks)}")
# Out:
# Total number of chunks: 842

# %%
for i in range(3):
    print(len(chunks[i]))
    print(chunks[i])
# Out:
# 7
# Comment
# 463
# This image shows two individuals walking on a dirt pathway through a wooded area. The foliage is dense on either side of the path, suggesting a natural, forested setting. The word "your" is superimposed on the image, which could imply that this is a frame from a video or a part of a series of images that conveys a message or a story. The scene appears calm, with no clear indications of the activity or mood of the persons, besides enjoying a walk in the woods.
# 436
# The image shows a forested area with tall trees and dense foliage. A dirt path leads through the forest, and there is a person visible walking along the path in the distance. The word "your" is overlaid on the image, which suggests that this might be a frame from a video that is conveying a message, perhaps part of a sentence that continues beyond this single frame. It looks peaceful and suggests an outdoor or nature-themed setting.

# %%
cdf = pd.DataFrame(chunks, columns=['Chunk'])
cdf
# Out:
#                                                  Chunk
# 0                                              Comment
# 1    This image shows two individuals walking on a ...
# 2    The image shows a forested area with tall tree...
# 3    In the image, there is a person who appears to...
# 4    The image shows a person walking on a path thr...
# ..                                                 ...
# 837  In the image, there is a group of American foo...
# 838  This image shows a scene of American football ...
# 839  In this image, we see a group of American foot...
# 840  This image shows a group of people playing Ame...
# 841  This image captures a moment from an American ...
#
# [842 rows x 1 columns]

# %%
# !pip install --upgrade --quiet "transformers>=4.36.2" "peft>=0.7.1" "accelerate>=0.25.0" "sentence-transformers"
# Out:
# WARNING: Ignoring invalid distribution ~ (C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\~-kenizers'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-llms-openai-like 0.1.3 requires transformers<5.0.0,>=4.37.0, but you have transformers 5.5.4 which is incompatible.
# WARNING: Ignoring invalid distribution ~ (C:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
import time 
from sentence_transformers import SentenceTransformer

embedding_model = "all-MiniLM-L6-v2"


def create_embeddings(chunks, embedding_model):
    model = SentenceTransformer(embedding_model)
    start_time = time.time()
    embeddings = model.encode(chunks, show_progress_bar=True)
    end_time = time.time()
    return embeddings

# %%
# Assuming 'chunks' is already initialized as a list of text segments you want to embed
embeddings = []

for i, chunk in enumerate(chunks):
    try:
        embeddings.append(create_embeddings([chunk], embedding_model)[0])
    except Exception as e:
        print(f"Error processing chunk {i+1}: {e}")
print(f"All chunks processed or attempted. Total embeddings successfully created: {len(embeddings)}.")
# Out:
# Error processing chunk 1: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 2: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 3: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 4: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 5: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 6: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 7: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 8: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 9: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 10: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 11: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 12: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 13: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 14: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 15: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 16: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 17: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 18: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 19: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 20: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 21: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 22: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 23: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 24: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 25: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 26: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 27: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 28: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 29: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 30: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 31: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 32: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 33: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 34: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 35: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 36: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 37: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 38: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 39: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 40: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 41: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 42: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 43: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 44: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 45: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 46: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 47: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 48: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 49: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 50: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 51: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 52: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 53: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 54: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 55: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 56: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 57: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 58: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 59: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 60: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 61: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 62: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 63: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 64: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 65: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 66: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 67: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 68: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 69: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 70: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 71: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 72: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 73: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 74: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 75: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 76: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 77: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 78: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 79: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 80: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 81: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 82: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 83: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 84: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 85: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 86: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 87: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 88: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 89: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 90: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 91: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 92: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 93: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 94: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 95: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 96: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 97: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 98: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 99: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 100: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 101: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 102: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 103: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 104: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 105: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 106: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 107: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 108: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 109: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 110: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 111: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 112: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 113: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 114: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 115: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 116: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 117: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 118: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 119: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 120: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 121: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 122: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 123: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 124: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 125: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 126: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 127: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 128: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 129: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 130: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 131: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 132: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 133: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 134: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 135: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 136: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 137: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 138: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 139: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 140: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# Error processing chunk 141: sentence-transformers/text-embedding-ada-002 is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# ...
#     941 load_kwargs = {
#     942     "token": token,
#     943     "cache_folder": cache_folder,
#    (...)    949     "config_kwargs": config_kwargs,
#     950 }
#     952 # Check if this is a Sentence Transformer model
# --> 953 modules_json_path = load_file_path(
#     954     model_name_or_path,
#     955     "modules.json",
#     956     token=token,
#     957     cache_folder=cache_folder,
#     958     revision=revision,
#     959     local_files_only=local_files_only,
#     960 )
#     961 if modules_json_path is None:
#     962     logger.info(f"No modules.json found for {model_name_or_path}, initializing a new {self.model_type} model.")
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\sentence_transformers\util\file_io.py:94, in load_file_path(model_name_or_path, filename, subfolder, token, cache_folder, revision, local_files_only)
#      92 file_path = Path(subfolder, filename)
#      93 try:
# ---> 94     return hf_hub_download(
#      95         model_name_or_path,
#      96         filename=file_path.name,
#      97         subfolder=file_path.parent.as_posix(),
#      98         revision=revision,
#      99         library_name="sentence-transformers",
#     100         token=token,
#     101         cache_dir=cache_folder,
#     102         local_files_only=local_files_only,
#     103     )
#     104 except Exception:
#     105     return None
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:997, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     976     return _hf_hub_download_to_local_dir(
#     977         # Destination
#     978         local_dir=local_dir,
#    (...)    994         dry_run=dry_run,
#     995     )
#     996 else:
# --> 997     return _hf_hub_download_to_cache_dir(
#     998         # Destination
#     999         cache_dir=cache_dir,
#    1000         # File info
#    1001         repo_id=repo_id,
#    1002         filename=filename,
#    1003         repo_type=repo_type,
#    1004         revision=revision,
#    1005         # HTTP info
#    1006         endpoint=endpoint,
#    1007         etag_timeout=etag_timeout,
#    1008         headers=hf_headers,
#    1009         token=token,
#    1010         # Additional options
#    1011         local_files_only=local_files_only,
#    1012         force_download=force_download,
#    1013         tqdm_class=tqdm_class,
#    1014         dry_run=dry_run,
#    1015     )
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:1072, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1068             return pointer_path
#    1070 # Try to get metadata (etag, commit_hash, url, size) from the server.
#    1071 # If we can't, a HEAD request error is returned.
# -> 1072 (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = _get_metadata_or_catch_error(
#    1073     repo_id=repo_id,
#    1074     filename=filename,
#    1075     repo_type=repo_type,
#    1076     revision=revision,
#    1077     endpoint=endpoint,
#    1078     etag_timeout=etag_timeout,
#    1079     headers=headers,
#    1080     token=token,
#    1081     local_files_only=local_files_only,
#    1082     storage_folder=storage_folder,
#    1083     relative_filename=relative_filename,
#    1084 )
#    1086 # etag can be None for several reasons:
#    1087 # 1. we passed local_files_only.
#    1088 # 2. we don't have a connection
#    (...)   1094 # If the specified revision is a commit hash, look inside "snapshots".
#    1095 # If the specified revision is a branch or tag, look inside "refs".
#    1096 if head_call_error is not None:
#    1097     # Couldn't make a HEAD call => let's try to find a local file
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:1669, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder, retry_on_errors)
#    1667 try:
#    1668     try:
# -> 1669         metadata = get_hf_file_metadata(
#    1670             url=url,
#    1671             timeout=etag_timeout,
#    1672             headers=headers,
#    1673             token=token,
#    1674             endpoint=endpoint,
#    1675             retry_on_errors=retry_on_errors,
#    1676         )
#    1677     except RemoteEntryNotFoundError as http_error:
#    1678         if storage_folder is not None and relative_filename is not None:
#    1679             # Cache the non-existence of the file
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:1591, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint, retry_on_errors)
#    1588 hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1590 # Retrieve metadata
# -> 1591 response = _httpx_follow_relative_redirects_with_backoff(
#    1592     method="HEAD", url=url, headers=hf_headers, timeout=timeout, retry_on_errors=retry_on_errors
#    1593 )
#    1594 hf_raise_for_status(response)
#    1596 # Return
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_http.py:685, in _httpx_follow_relative_redirects_with_backoff(method, url, retry_on_errors, **httpx_kwargs)
#     680 no_retry_kwargs: dict[str, Any] = (
#     681     {} if retry_on_errors else {"retry_on_exceptions": (), "retry_on_status_codes": ()}
#     682 )
#     684 while True:
# --> 685     response = http_backoff(
#     686         method=method,
#     687         url=url,
#     688         **httpx_kwargs,
#     689         follow_redirects=False,
#     690         **no_retry_kwargs,
#     691     )
#     692     hf_raise_for_status(response)
#     694     # Check if response is a relative redirect
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_http.py:559, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     494 def http_backoff(
#     495     method: HTTP_METHOD_T,
#     496     url: str,
#    (...)    503     **kwargs,
#     504 ) -> httpx.Response:
#     505     """Wrapper around httpx to retry calls on an endpoint, with exponential backoff.
#     506
#     507     Endpoint call is retried on exceptions (ex: connection timeout, proxy error,...)
#    (...)    557     > issue on [Github](https://github.com/huggingface/huggingface_hub).
#     558     """
# --> 559     return next(
#     560         _http_backoff_base(
#     561             method=method,
#     562             url=url,
#     563             max_retries=max_retries,
#     564             base_wait_time=base_wait_time,
#     565             max_wait_time=max_wait_time,
#     566             retry_on_exceptions=retry_on_exceptions,
#     567             retry_on_status_codes=retry_on_status_codes,
#     568             stream=False,
#     569             **kwargs,
#     570         )
#     571     )
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\utils\_http.py:467, in _http_backoff_base(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, stream, **kwargs)
#     465             return
#     466 else:
# --> 467     response = client.request(method=method, url=url, **kwargs)
#     468     if not _should_retry(response):
#     469         yield response
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File c:\Users\dorot\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
print(f"Number of embeddings: {len(embeddings)}")
# Out:
# Number of embeddings: 842

# %%
print("First embedding overall structure:", embeddings[0])
# Out:
# First embedding overall structure: [-1.07446685e-01  1.89448893e-02 -4.79012579e-02  1.74092390e-02
#  -1.93158723e-02 -4.53877635e-02  6.26516715e-02  1.03360817e-01
#   1.56058660e-02 -9.61713027e-03 -2.47128103e-02 -7.27570131e-02
#  -4.26438637e-03  2.73291059e-02 -1.64218210e-02  4.06363867e-02
#  -2.81192642e-02 -5.88444360e-02 -1.65632784e-01 -6.97765723e-02
#   2.09931470e-02 -2.18020603e-02 -5.07035702e-02  1.01752514e-02
#  -1.44181196e-02 -6.23919182e-02  1.68200824e-02 -2.48843152e-03
#   1.87753662e-02 -5.25082722e-02 -5.60009805e-03  1.33281738e-01
#  -9.70125012e-03  1.35575989e-02  2.34328005e-02  3.99517976e-02
#  -1.02596417e-01 -8.03380534e-02 -1.51216630e-02 -4.21551941e-03
#   9.01025161e-03 -3.51900570e-02  1.04830392e-01 -3.30486223e-02
#  -1.06976749e-02 -3.24649476e-02  3.72499153e-02 -3.48865725e-02
#  -5.53645417e-02  9.45176650e-03 -2.79597193e-02 -5.03423102e-02
#  -2.55657658e-02 -4.17688154e-02  3.07722557e-02 -2.42509898e-02
#  -9.72708967e-03  1.74309232e-03  2.06714775e-02  6.28977567e-02
#  -1.19599411e-02  4.55530509e-02 -6.66635856e-02  1.02546230e-01
#   1.19897425e-01 -1.40804714e-02  7.56662339e-02  3.32956724e-02]

# %%
first_embedding = embeddings[0]

if isinstance(first_embedding, np.ndarray):
    print("First embedding is a numpy array.")
    print("Shape:", first_embedding.shape)
    print("Data Type:", first_embedding.dtype)
    print("First few elements:", first_embedding[:10])
elif isinstance(first_embedding, list):
    print("First embedding is a list.")
    print("Length:", len(first_embedding))
    print("First few elements:", first_embedding[:10])
else:
    print("Unknown format of the embedding:", type(first_embedding))
# Out:
# First embedding is a numpy array.
# Shape: (384,)
# Data Type: float32
# First few elements: [-0.10744669  0.01894489 -0.04790126  0.01740924 -0.01931587 -0.04538776
#   0.06265167  0.10336082  0.01560587 -0.00961713]

# %%
pure_embeddings = list(embeddings)

# %%
r=len(pure_embeddings)
print(r)
# Out:
# 842

# %%
num_chunks = len(chunks)
print(f"Number of chunks: {num_chunks}")
# Out:
# Number of chunks: 842

# %%
seen_chunks = set()
duplicate_chunks = []

for chunk in chunks:
    if chunk in seen_chunks:
        duplicate_chunks.append(chunk)
    else:
        seen_chunks.add(chunk)

print(f"Number of duplicate chunks: {len(duplicate_chunks)}")
# Out:
# Number of duplicate chunks: 19

# %%
num_chunks = len(chunks)
print(f"Number of chunks: {num_chunks}")
print(f"Number of embeddings: {len(pure_embeddings)}")
# Out:
# Number of chunks: 842
# Number of embeddings: 842

# %%
assert len(chunks) == len(pure_embeddings), "Mismatch between number of chunks and embeddings"

# %% [markdown]
# ### The Pinecone index

# %%
import os
from pinecone import Pinecone, ServerlessSpec

api_key = os.environ.get('PINECONE_API_KEY') or 'PINECONE_API_KEY'

from pinecone import Pinecone, ServerlessSpec
pc = Pinecone(api_key=api_key)

# %%
from pinecone import ServerlessSpec

index_name = 'videos-sports-us' 
cloud = os.environ.get('PINECONE_CLOUD') or 'aws'
region = os.environ.get('PINECONE_REGION') or 'us-east-1'

spec = ServerlessSpec(cloud=cloud, region=region)

# %%
import time
import pinecone
if index_name not in pc.list_indexes().names():
    pc.create_index(
        index_name,
        dimension=384, 
        metric='cosine',
        spec=spec
    )
    time.sleep(1)

# %%
index = pc.Index(index_name)
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %% [markdown]
# ### Upserting

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842 entries, 0 to 841
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           842 non-null    object
#  1   FrameNumber  842 non-null    object
#  2   Comment      842 non-null    object
#  3   FileName     842 non-null    object
# dtypes: object(4)
# memory usage: 26.4+ KB

# %%
len(df)
# Out:
# 842

# %%
for index, row in df.iterrows():
    if row.isnull().any(): 
        print(f"NaN found at index {index}:")
        print(row)

# %%
index = pc.Index(index_name)
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %%
start_time = time.time()

data_for_upsert = [
    {
        "id": str(df['ID'].iloc[i]),  # Use existing IDs as string
        "values": pure_embeddings[i],
        "metadata": {
            "text": df['Comment'].iloc[i],
            "frame_number": df['FrameNumber'].iloc[i],
            "file_name": df['FileName'].iloc[i]
        }
    }
    for i in range(len(df))
]

batch_size = 100  
def upsert_in_batches(data, batch_size):
    for start in range(0, len(data), batch_size):
        end = start + batch_size
        batch = data[start:end]
        try:
            index.upsert(vectors=batch)
            print(f"Upserted batch from index {start} to {end - 1}")
        except Exception as e:
            print(f"Failed to upsert batch from index {start} to {end - 1}: {e}")

upsert_in_batches(data_for_upsert, batch_size)
response_time = time.time() - start_time
print(f"Total upsertion time: {response_time:.2f} seconds")
# Out:
# Failed to upsert batch from index 0 to 99: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Wed, 15 Apr 2026 20:39:10 GMT', 'Content-Type': 'application/json', 'Content-Length': '103', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1372', 'x-envoy-upstream-service-time': '32', 'x-pinecone-response-duration-ms': '1373', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 1536","details":[]}
#
# Failed to upsert batch from index 100 to 199: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Wed, 15 Apr 2026 20:39:12 GMT', 'Content-Type': 'application/json', 'Content-Length': '103', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1128', 'x-envoy-upstream-service-time': '2', 'x-pinecone-response-duration-ms': '1129', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 1536","details":[]}
#
# Failed to upsert batch from index 200 to 299: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Wed, 15 Apr 2026 20:39:13 GMT', 'Content-Type': 'application/json', 'Content-Length': '103', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1147', 'x-envoy-upstream-service-time': '38', 'x-pinecone-response-duration-ms': '1159', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 1536","details":[]}
#
# Failed to upsert batch from index 300 to 399: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Wed, 15 Apr 2026 20:39:14 GMT', 'Content-Type': 'application/json', 'Content-Length': '103', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1118', 'x-envoy-upstream-service-time': '2', 'x-pinecone-response-duration-ms': '1121', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 1536","details":[]}
#
# Failed to upsert batch from index 400 to 499: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Wed, 15 Apr 2026 20:39:16 GMT', 'Content-Type': 'application/json', 'Content-Length': '103', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1146', 'x-envoy-upstream-service-time': '27', 'x-pinecone-response-duration-ms': '1147', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 1536","details":[]}
#
# Failed to upsert batch from index 500 to 599: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Wed, 15 Apr 2026 20:39:17 GMT', 'Content-Type': 'application/json', 'Content-Length': '103', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1159', 'x-envoy-upstream-service-time': '4', 'x-pinecone-response-duration-ms': '1162', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 1536","details":[]}
#
# Failed to upsert batch from index 600 to 699: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Wed, 15 Apr 2026 20:39:19 GMT', 'Content-Type': 'application/json', 'Content-Length': '103', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1123', 'x-envoy-upstream-service-time': '3', 'x-pinecone-response-duration-ms': '1126', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 1536","details":[]}
#
# Failed to upsert batch from index 700 to 799: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Wed, 15 Apr 2026 20:39:20 GMT', 'Content-Type': 'application/json', 'Content-Length': '103', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1137', 'x-envoy-upstream-service-time': '2', 'x-pinecone-response-duration-ms': '1140', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 1536","details":[]}
#
# Failed to upsert batch from index 800 to 899: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Wed, 15 Apr 2026 20:39:21 GMT', 'Content-Type': 'application/json', 'Content-Length': '103', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '415', 'x-envoy-upstream-service-time': '11', 'x-pinecone-response-duration-ms': '419', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 1536","details":[]}
#
# Total upsertion time: 12.05 seconds

# %% [markdown]
# ### Statistics after upserting

# %%
print(index.describe_index_stats(include_metadata=True))

# %%
index_info = index.describe_index_stats(include_metadata=True)

dimensions_per_vector = index_info['dimension']
total_vectors = index_info['total_vector_count']  

print(f"Dimensions per vector: {dimensions_per_vector}")
print(f"Total vectors: {total_vectors}")

bytes_per_float = 4
bytes_per_vector = dimensions_per_vector * bytes_per_float
total_bytes = bytes_per_vector * total_vectors
total_megabytes = total_bytes / (1024 ** 2)

print(f"Total estimated size of the index: {total_megabytes:.2f} MB")

# %% [markdown]
# ### Querying vector store after upserting the dataset

# %%
k = 1

# %%
query_text = "Find a basketball player that is scoring with a dunk."

# %%
import time

# Start timing before the request
start_time = time.time()

# Target vector
query_embedding = create_embeddings(query_text, model=embedding_model)

query_results = index.query(vector=query_embedding, top_k=k, include_metadata=True)  # Request metadata

print("Query Results:")
for match in query_results['matches']:
    print(f"ID: {match['id']}, Score: {match['score']}")

    if 'metadata' in match:
        metadata = match['metadata']
        text = metadata.get('text', "No text metadata available.")
        frame_number = metadata.get('frame_number', "No frame number available.")
        file_name = metadata.get('file_name', "No file name available.")

        print(f"Text: {text}")
        print(f"Frame Number: {frame_number}")
        print(f"File Name: {file_name}")
    else:
        print("No metadata available.")

response_time = time.time() - start_time
print(f"Querying response time: {response_time:.2f} seconds")

# %%
print(file_name)

# %%
def display_video(file_name):
  with open(file_name, 'rb') as file:
      video_data = file.read()

  video_url = b64encode(video_data).decode()

  html = f'''
  <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{video_url}" type="video/mp4">
  Your browser does not support the video tag.
  </video>
  '''
  HTML(html)
  return HTML(html)

# %%
display_video(file_name)

# %%
file_name_root = file_name.split('.')[0]
print(file_name_root)

# %%
frame_number
